# %%
import os
from pathlib import Path
import matplotlib.pyplot as plt

while ".git" not in os.listdir(os.getcwd()): os.chdir(Path(os.getcwd())/"..")
os.getcwd()

from utils.coords import *

# %%
bbox = (16.40087983537872, 48.210066700455656, 16.404527639638978, 48.21149662294165)
img = getImgFor(bbox, 20, layer = "lb2020")
plt.imshow(img)
# Out:
# (16.40087983537872, 48.210066700455656, 16.404527639638978, 48.21149662294165)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /home/preschen/prj/ortho-vienna/playground/model/carDetection.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell://pugsley:11230/home/preschen/prj/ortho-vienna/playground/model/carDetection.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> bbox = (16.40087983537872, 48.210066700455656, 16.404527639638978, 48.21149662294165)
# ----> <a href='vscode-notebook-cell://pugsley:11230/home/preschen/prj/ortho-vienna/playground/model/carDetection.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> img = getImgFor(bbox, 20, layer = "lb2020")
#       <a href='vscode-notebook-cell://pugsley:11230/home/preschen/prj/ortho-vienna/playground/model/carDetection.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> plt.imshow(img)
#
# ...

# %%
bbox = (16.389168798923496, 48.18125179031228, 16.390992701053623, 48.18196715875446)
img = getImgFor(bbox, 20, layer = "lb2020")
img.save('tmp/wifo.png')
plt.imshow(img)
# Out:
# (16.389168798923496, 48.18125179031228, 16.390992701053623, 48.18196715875446)
# [234, 162, 1594, 962]

# %%
bbox = (1822159.6250, 6144464.5671, 1822405.6567, 6144684.9207)
img = getImgFor(bbox, 20, wmts, layer = "lb2020", epsg = 3857)
img.save('tmp/gauss.png')
plt.imshow(img)
# Out:
# (16.368738412429956, 48.22557324856525, 16.370948552794836, 48.22689195388285)
# [104, 76, 1752, 1552]

# %%
# bbox = (1820530, 6142779, 1823883, 6145305)
bbox = (1821567, 6141073, 1821786, 6141235)
img = getImgFor(bbox, 20, layer = "lb2021", epsg = 3857)
img.save('tmp/helden.png')
plt.imshow(img)
# Out:
# (16.363414771477444, 48.20527214145943, 16.365382081949665, 48.206242017661545)
# [230, 145, 1697, 1230]
